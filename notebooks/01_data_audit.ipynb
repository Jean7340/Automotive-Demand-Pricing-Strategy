# %%
import pandas as pd
import numpy as np

cars = pd.read_csv("../data/cars.csv", encoding="latin1")
cars.columns = cars.columns.str.strip()

cars.shape
cars.head()
cars.info()
cars.describe()
cars.isna().mean().sort_values(ascending=False).head(15)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11431 entries, 0 to 11430
# Data columns (total 54 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ye            11431 non-null  int64
#  1   ma            11431 non-null  int64
#  2   co            11431 non-null  int64
#  3   zcode         11431 non-null  int64
#  4   brd           11431 non-null  int64
#  5   type          11431 non-null  object
#  6   brand         11431 non-null  object
#  7   model         11403 non-null  object
#  8   org           11431 non-null  int64
#  9   loc           11431 non-null  int64
#  10  cla           11431 non-null  int64
#  11  home          11431 non-null  int64
#  12  frm           11431 non-null  int64
#  13  qu            11431 non-null  int64
#  14  cy            11431 non-null  float64
#  15  hp            11431 non-null  float64
#  16  we            11431 non-null  int64
#  17  pl            11431 non-null  float64
# ...

# %% [markdown]
# ### Business Implication
#
# The dataset is suitable for demand and pricing analysis because core variables such as quantity sold, price, brand, vehicle attributes, market, and year are complete. Missing values are concentrated in auxiliary market-level variables, which can be handled separately during modeling.
